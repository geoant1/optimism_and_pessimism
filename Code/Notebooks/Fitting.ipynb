# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
folder = '/Users/GA/Documents/Dayan_lab/Optimism_And_Pessimism_In_Optimised_Replay/Data/fits'

# %%
sub = 11
z   = pd.read_csv(os.path.join(folder, 'save_params_%u'%sub, 'backup.txt'), sep='\t')

# %%
vals = (1-z[' param#8 '].values)

# %%
plt.figure(figsize=(5, 3),dpi=100)
plt.scatter(range(len(vals)), vals)
plt.ylim(-0.1, 1.1)
plt.ylabel(r'$\phi^{MB}$', fontsize=14)
plt.xlabel('Fitting iteration', fontsize=14)
# Out:
# Text(0.5, 0, 'Fitting iteration')

# %%
stds = np.logspace(np.log10(0.5), np.log10(0.01), 55)

# %%
xs   = np.arange(55)
ys   = np.ones(55)*0.5

# %%
plt.figure(figsize=(5, 3),dpi=100)
plt.fill_between(xs, ys+stds, ys-stds, alpha=0.5)
plt.ylabel('Parameter value', fontsize=14)
plt.xlabel('Fitting iteration', fontsize=14)
# Out:
# Text(0.5, 0, 'Fitting iteration')
